# %% [markdown]
# # Prepare a prediction model for profit of 50_startups data. Do transformations for getting better predictions of profit and make a table containing R^2 value for each prepared model. R&D Spend -- Research and devolop spend in the past few years Administration -- spend on administration in the past few years Marketing Spend -- spend on Marketing in the past few years State -- states from which data is collected Profit -- profit of each state in the past few years¶

# %%
#Import the data
import pandas as pd

# %%
dm = pd.read_csv("/content/50_Startups.csv")
dm
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# 12   93863.75       127320.38        249839.44     Florida  141585.52
# 13   91992.39       135495.07        252664.93  California  134307.35
# 14  119943.24       156547.42        256512.92     Florida  132602.65
# 15  114523.61       122616.84        261776.23    New York  129917.04
# 16   78013.11       121597.55        264346.06  California  126992.93
# 17   94657.16       145077.58        282574.31    New York  125370.37
# 18   91749.16       114175.79        294919.57     Florida  124266.90
# 19   86419.70       153514.11             0.00    New York  122776.86
# 20   76253.86       113867.30        298664.47  California  118474.03
# 21   78389.47       153773.43        299737.29    New York  111313.02
# 22   73994.56       122782.75        303319.26     Florida  110352.25
# 23   67532.53       105751.03        304768.73     Florida  108733.99
# 24   77044.01        99281.34        140574.81    New York  108552.04
# 25   64664.71       139553.16        137962.62  California  107404.34
# 26   75328.87       144135.98        134050.07     Florida  105733.54
# 27   72107.60       127864.55        353183.81    New York  105008.31
# 28   66051.52       182645.56        118148.20     Florida  103282.38
# 29   65605.48       153032.06        107138.38    New York  101004.64
# 30   61994.48       115641.28         91131.24     Florida   99937.59
# 31   61136.38       152701.92         88218.23    New York   97483.56
# 32   63408.86       129219.61         46085.25  California   97427.84
# 33   55493.95       103057.49        214634.81     Florida   96778.92
# 34   46426.07       157693.92        210797.67  California   96712.80
# 35   46014.02        85047.44        205517.64    New York   96479.51
# 36   28663.76       127056.21        201126.82     Florida   90708.19
# 37   44069.95        51283.14        197029.42  California   89949.14
# 38   20229.59        65947.93        185265.10    New York   81229.06
# 39   38558.51        82982.09        174999.30  California   81005.76
# 40   28754.33       118546.05        172795.67  California   78239.91
# 41   27892.92        84710.77        164470.71     Florida   77798.83
# 42   23640.93        96189.63        148001.11  California   71498.49
# 43   15505.73       127382.30         35534.17    New York   69758.98
# 44   22177.74       154806.14         28334.72  California   65200.33
# 45    1000.23       124153.04          1903.93    New York   64926.08
# 46    1315.46       115816.21        297114.46     Florida   49490.75
# 47       0.00       135426.92             0.00  California   42559.73
# 48     542.05        51743.15             0.00    New York   35673.41
# 49       0.00       116983.80         45173.06  California   14681.40

# %%
#check for missing values
dm.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
#Encoding

mappings = {}
for i in dict(dm.dtypes):
 if dict(dm.dtypes)[i] == 'O':
  mappings[i] = dict(zip(dm[i].unique(), range(len(dm[i].unique()))))
  dm[i] = dm[i].map(lambda x: mappings[i][x])
dm
# Out:
#     R&D Spend  Administration  Marketing Spend  State     Profit
# 0   165349.20       136897.80        471784.10      0  192261.83
# 1   162597.70       151377.59        443898.53      1  191792.06
# 2   153441.51       101145.55        407934.54      2  191050.39
# 3   144372.41       118671.85        383199.62      0  182901.99
# 4   142107.34        91391.77        366168.42      2  166187.94
# 5   131876.90        99814.71        362861.36      0  156991.12
# 6   134615.46       147198.87        127716.82      1  156122.51
# 7   130298.13       145530.06        323876.68      2  155752.60
# 8   120542.52       148718.95        311613.29      0  152211.77
# 9   123334.88       108679.17        304981.62      1  149759.96
# 10  101913.08       110594.11        229160.95      2  146121.95
# 11  100671.96        91790.61        249744.55      1  144259.40
# 12   93863.75       127320.38        249839.44      2  141585.52
# 13   91992.39       135495.07        252664.93      1  134307.35
# 14  119943.24       156547.42        256512.92      2  132602.65
# 15  114523.61       122616.84        261776.23      0  129917.04
# 16   78013.11       121597.55        264346.06      1  126992.93
# 17   94657.16       145077.58        282574.31      0  125370.37
# 18   91749.16       114175.79        294919.57      2  124266.90
# 19   86419.70       153514.11             0.00      0  122776.86
# 20   76253.86       113867.30        298664.47      1  118474.03
# 21   78389.47       153773.43        299737.29      0  111313.02
# 22   73994.56       122782.75        303319.26      2  110352.25
# 23   67532.53       105751.03        304768.73      2  108733.99
# 24   77044.01        99281.34        140574.81      0  108552.04
# 25   64664.71       139553.16        137962.62      1  107404.34
# 26   75328.87       144135.98        134050.07      2  105733.54
# 27   72107.60       127864.55        353183.81      0  105008.31
# 28   66051.52       182645.56        118148.20      2  103282.38
# 29   65605.48       153032.06        107138.38      0  101004.64
# 30   61994.48       115641.28         91131.24      2   99937.59
# 31   61136.38       152701.92         88218.23      0   97483.56
# 32   63408.86       129219.61         46085.25      1   97427.84
# 33   55493.95       103057.49        214634.81      2   96778.92
# 34   46426.07       157693.92        210797.67      1   96712.80
# 35   46014.02        85047.44        205517.64      0   96479.51
# 36   28663.76       127056.21        201126.82      2   90708.19
# 37   44069.95        51283.14        197029.42      1   89949.14
# 38   20229.59        65947.93        185265.10      0   81229.06
# 39   38558.51        82982.09        174999.30      1   81005.76
# 40   28754.33       118546.05        172795.67      1   78239.91
# 41   27892.92        84710.77        164470.71      2   77798.83
# 42   23640.93        96189.63        148001.11      1   71498.49
# 43   15505.73       127382.30         35534.17      0   69758.98
# 44   22177.74       154806.14         28334.72      1   65200.33
# 45    1000.23       124153.04          1903.93      0   64926.08
# 46    1315.46       115816.21        297114.46      2   49490.75
# 47       0.00       135426.92             0.00      1   42559.73
# 48     542.05        51743.15             0.00      0   35673.41
# 49       0.00       116983.80         45173.06      1   14681.40

# %%
# Standardization Y variable
from sklearn.preprocessing import MinMaxScaler
MM = MinMaxScaler()
dm["Profit"] =pd.DataFrame(MM.fit_transform(dm[["Profit"]]))
dm["Profit"]
# Out:
# 0     1.000000
# 1     0.997355
# 2     0.993178
# 3     0.947292
# 4     0.853171
# 5     0.801382
# 6     0.796490
# 7     0.794407
# 8     0.774468
# 9     0.760661
# 10    0.740175
# 11    0.729686
# 12    0.714629
# 13    0.673644
# 14    0.664044
# 15    0.648921
# 16    0.632454
# 17    0.623317
# 18    0.617103
# 19    0.608713
# 20    0.584482
# 21    0.544157
# 22    0.538747
# 23    0.529634
# 24    0.528609
# 25    0.522146
# 26    0.512737
# 27    0.508654
# 28    0.498934
# 29    0.486108
# 30    0.480099
# 31    0.466280
# 32    0.465966
# 33    0.462312
# 34    0.461939
# 35    0.460626
# 36    0.428126
# 37    0.423852
# 38    0.374747
# 39    0.373489
# 40    0.357914
# 41    0.355430
# 42    0.319951
# 43    0.310156
# 44    0.284485
# 45    0.282940
# 46    0.196020
# 47    0.156990
# 48    0.118211
# 49    0.000000
# Name: Profit, dtype: float64

# %%
#Feature selection

import matplotlib.pyplot as plt

import seaborn as sns
plt.figure(figsize = (6,5))
corr = dm.corr()

sns.heatmap(data = corr, annot = True, fmt = '.2g', linewidth = 1)
plt.show()

# %%
#EDA
# Format the plot background and scatter plots for all the variables
import seaborn as sns
sns.set_style(style="darkgrid")
sns.pairplot(dm)

# %%
##  Split the variables as X and Y

X = dm[["R&D Spend"]]                                                  #== Case-1

Y = dm["Profit"]

# %%
# Model fitting

from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(X,Y)
# Out:
# LinearRegression()

# %%
# Model predicted values
Y_pred = LR.predict(X)
Y_pred
# Out:
# array([0.98889215, 0.97565543, 0.93160748, 0.8879785 , 0.87708186,
#        0.82786598, 0.84104045, 0.82027095, 0.77333935, 0.78677264,
#        0.68371816, 0.67774746, 0.64499501, 0.6359924 , 0.77045637,
#        0.744384  , 0.56874187, 0.64881189, 0.63482229, 0.6091837 ,
#        0.56027859, 0.57055244, 0.54940971, 0.51832264, 0.56407979,
#        0.50452633, 0.55582872, 0.54033206, 0.5111979 , 0.50905212,
#        0.49168058, 0.48755249, 0.49848478, 0.46040829, 0.41678517,
#        0.41480291, 0.33133551, 0.40545052, 0.290761  , 0.37893647,
#        0.33177122, 0.32762721, 0.30717203, 0.26803579, 0.30013302,
#        0.19825375, 0.19977024, 0.19344192, 0.19604957, 0.19344192])

# %%
# Model evaluation

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(Y,Y_pred)
print("Mean square error ",mse.round(3))

import numpy as np
print("Root mean square error ", np.sqrt(mse).round(3))
# Out:
# Mean square error  0.003
# Root mean square error  0.052

# %%
from sklearn.metrics import r2_score
r2 = r2_score(Y,Y_pred)
print("r2_score",r2.round(3))
# Out:
# r2_score 0.947

# %%
X = dm[["R&D Spend","Marketing Spend"]]                              #== Case-2
# Model fitting

from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(X,Y)
# Model predicted values
Y_pred = LR.predict(X)
Y_pred
# Model evaluation

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(Y,Y_pred)
print("Mean square error ",mse.round(3))

import numpy as np
print("Root mean square error ", np.sqrt(mse).round(3))
# Out:
# Mean square error  0.003
# Root mean square error  0.05

# %%
r2 = r2_score(Y,Y_pred)
print("r2_score",r2.round(3))
# Out:
# r2_score 0.95

# %%
X = dm[["R&D Spend","Marketing Spend","Administration"]]                      #== Case-3
# Model fitting

from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(X,Y)
# Model predicted values
Y_pred = LR.predict(X)
Y_pred
# Model evaluation

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(Y,Y_pred)
print("Mean square error ",mse.round(3))

import numpy as np
print("Root mean square error ", np.sqrt(mse).round(3))
# Out:
# Mean square error  0.002
# Root mean square error  0.05

# %%
r2 = r2_score(Y,Y_pred)
print("r2_score",r2.round(3))
# Out:
# r2_score 0.951

# %%
X = dm[["R&D Spend","Marketing Spend","Administration","State"]]         #== Case-4
# Model fitting

from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(X,Y)
# Model predicted values
Y_pred = LR.predict(X)
Y_pred
# Model evaluation

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(Y,Y_pred)
print("Mean square error ",mse.round(3))

import numpy as np
print("Root mean square error ", np.sqrt(mse).round(3))
# Out:
# Mean square error  0.002
# Root mean square error  0.05

# %%
r2 = r2_score(Y,Y_pred)
print("r2_score",r2.round(3))
# Out:
# r2_score 0.951

# %%
## R2 values with cases without model improvement
# Case-1      r2_score 0.947
# Case-2      r2_score 0.950
# Case-3      r2_score 0.951
# Case-4      r2_score 0.951

# %% [markdown]
# # **Improving the model by by Data cleaning**

# %%
## Built full model
import statsmodels.api as sm

model = sm.OLS(Y, X)  # Capitalize OLS
model = model.fit()

# %%
#Variance Inflation Factor (VIF) is a measure of multicollinearity

from statsmodels.stats.outliers_influence import variance_inflation_factor

X1 = dm[["R&D Spend","Marketing Spend","Administration","State"]]
vif = [variance_inflation_factor(X1.values, i) for i in range(X1.shape[1])]
vif

## R&D Spend and Marketing Spend are having moderate level of multicollinearity issuess
# Out:
# [8.563613888812206, 8.1201510466834, 4.893955804957631, 2.4647638730268473]

# %%
# residual analysis by using Q-Q plot

import matplotlib.pyplot as plt

QQ_plot = sm.qqplot(model.resid,line="q")
plt.title("Normal Q-Q plot of residuals")
plt.show()

list(np.where(model.resid>10))             # No residuals found
# Out:
# [array([], dtype=int64)]

# %%
# Residual plot for homoscedasticity

model.fittedvalues
model.resid

plt.scatter(model.fittedvalues,model.resid)
plt.title("Residual plot")
plt.xlabel("Fitted values")
plt.ylabel("residual value")
plt.show()

# %%
#Residual Vs Regressors
fig=plt.figure(figsize=(15,8))
fig=sm.graphics.plot_regress_exog(model,"Administration",fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
fig=sm.graphics.plot_regress_exog(model,"R&D Spend",fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
fig=sm.graphics.plot_regress_exog(model,"Marketing Spend",fig=fig)
plt.show()

# %%
# Model Deletion Diagnostics
# Detecting Influencers/Outliers
# Cook’s Distance

model_influence = model.get_influence()
(cooks , P_value) = model_influence.cooks_distance
(cooks , P_value)
# Out:
# (array([1.10638708e-02, 8.30950205e-03, 4.09281758e-02, 2.82684717e-02,
#         8.33658226e-05, 8.93248641e-05, 1.43822801e-04, 1.77023549e-02,
#         3.10753779e-03, 1.60645429e-04, 3.04575928e-02, 1.97671151e-02,
#         1.23837224e-02, 8.85910412e-04, 9.31224251e-02, 2.38496999e-02,
#         4.80604582e-03, 1.25990640e-02, 3.15156781e-03, 5.66558820e-02,
#         3.24736249e-04, 4.44059041e-02, 8.93245431e-03, 2.84002704e-04,
#         2.70726172e-03, 1.20265489e-03, 1.04844183e-02, 5.77571914e-02,
#         2.63170702e-02, 1.04076023e-03, 5.38246833e-03, 3.37503547e-04,
#         1.51991830e-03, 4.54054355e-04, 2.30140285e-04, 2.37800978e-02,
#         2.66029225e-02, 1.60720912e-02, 8.63676480e-02, 2.11540156e-03,
#         1.75900408e-03, 1.76647395e-02, 3.98950889e-03, 3.40451775e-02,
#         1.44411599e-03, 1.10204952e-01, 1.20689324e-01, 1.57017189e-03,
#         2.81062854e-03, 1.23611592e-01]),
#  array([0.9997486 , 0.99985762, 0.99670445, 0.99839901, 0.99999999,
#         0.99999998, 0.99999996, 0.99936253, 0.99997994, 0.99999995,
#         0.9981473 , 0.99920752, 0.99968564, 0.99999836, 0.98416271,
#         0.99885314, 0.99995213, 0.99967471, 0.99997937, 0.99382564,
#         0.99999978, 0.99613991, 0.99983562, 0.99999983, 0.99998476,
#         0.99999699, 0.99977405, 0.99359335, 0.99860852, 0.99999774,
#         0.99994001, 0.99999976, 0.99999519, 0.99999957, 0.99999989,
#         0.99885971, 0.99857871, 0.9994733 , 0.9862459 , 0.99999069,
#         0.99999356, 0.9993652 , 0.99996698, 0.99769704, 0.99999566,
#         0.97834835, 0.97441328, 0.99999487, 0.99998358, 0.97326925]))

# %%
# Plot the influence values using the stemplot

fig = plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(dm)),np.round(cooks,3))
plt.xlabel("Row index")
plt.ylabel("Cooks dis")
plt.show()

# %%
#index and value of influencer where c is more than 0.5
(np.argmax(cooks),np.max(cooks))
# Out:
# (49, 0.1236115918039394)

# %%
# High Influence points

from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()     # from the plot 38,46 and 49(from cooks distance) are the highly influencers

# %%
# Removing influencer points
dm[dm.index.isin([38,46,49])]
# Out:
#     R&D Spend  Administration  Marketing Spend  State    Profit
# 38   20229.59        65947.93        185265.10      0  0.374747
# 46    1315.46       115816.21        297114.46      2  0.196020
# 49       0.00       116983.80         45173.06      1  0.000000

# %%
dm_new = dm

# %%
dm_new = dm_new.drop(["Marketing Spend"],axis=1)
dm_new                   # R&D Spend and Marketing Spend are having moderate level of multicollinearity issues
# Out:
#     R&D Spend  Administration  State    Profit
# 0   165349.20       136897.80      0  1.000000
# 1   162597.70       151377.59      1  0.997355
# 2   153441.51       101145.55      2  0.993178
# 3   144372.41       118671.85      0  0.947292
# 4   142107.34        91391.77      2  0.853171
# 5   131876.90        99814.71      0  0.801382
# 6   134615.46       147198.87      1  0.796490
# 7   130298.13       145530.06      2  0.794407
# 8   120542.52       148718.95      0  0.774468
# 9   123334.88       108679.17      1  0.760661
# 10  101913.08       110594.11      2  0.740175
# 11  100671.96        91790.61      1  0.729686
# 12   93863.75       127320.38      2  0.714629
# 13   91992.39       135495.07      1  0.673644
# 14  119943.24       156547.42      2  0.664044
# 15  114523.61       122616.84      0  0.648921
# 16   78013.11       121597.55      1  0.632454
# 17   94657.16       145077.58      0  0.623317
# 18   91749.16       114175.79      2  0.617103
# 19   86419.70       153514.11      0  0.608713
# 20   76253.86       113867.30      1  0.584482
# 21   78389.47       153773.43      0  0.544157
# 22   73994.56       122782.75      2  0.538747
# 23   67532.53       105751.03      2  0.529634
# 24   77044.01        99281.34      0  0.528609
# 25   64664.71       139553.16      1  0.522146
# 26   75328.87       144135.98      2  0.512737
# 27   72107.60       127864.55      0  0.508654
# 28   66051.52       182645.56      2  0.498934
# 29   65605.48       153032.06      0  0.486108
# 30   61994.48       115641.28      2  0.480099
# 31   61136.38       152701.92      0  0.466280
# 32   63408.86       129219.61      1  0.465966
# 33   55493.95       103057.49      2  0.462312
# 34   46426.07       157693.92      1  0.461939
# 35   46014.02        85047.44      0  0.460626
# 36   28663.76       127056.21      2  0.428126
# 37   44069.95        51283.14      1  0.423852
# 38   20229.59        65947.93      0  0.374747
# 39   38558.51        82982.09      1  0.373489
# 40   28754.33       118546.05      1  0.357914
# 41   27892.92        84710.77      2  0.355430
# 42   23640.93        96189.63      1  0.319951
# 43   15505.73       127382.30      0  0.310156
# 44   22177.74       154806.14      1  0.284485
# 45    1000.23       124153.04      0  0.282940
# 46    1315.46       115816.21      2  0.196020
# 47       0.00       135426.92      1  0.156990
# 48     542.05        51743.15      0  0.118211
# 49       0.00       116983.80      1  0.000000

# %%
dm_new = dm_new.drop(dm_new.index[[38,46,49]],axis=0).reset_index()
dm_new                   # High influence points
# Out:
#     index  R&D Spend  Administration  State    Profit
# 0       0  165349.20       136897.80      0  1.000000
# 1       1  162597.70       151377.59      1  0.997355
# 2       2  153441.51       101145.55      2  0.993178
# 3       3  144372.41       118671.85      0  0.947292
# 4       4  142107.34        91391.77      2  0.853171
# 5       5  131876.90        99814.71      0  0.801382
# 6       6  134615.46       147198.87      1  0.796490
# 7       7  130298.13       145530.06      2  0.794407
# 8       8  120542.52       148718.95      0  0.774468
# 9       9  123334.88       108679.17      1  0.760661
# 10     10  101913.08       110594.11      2  0.740175
# 11     11  100671.96        91790.61      1  0.729686
# 12     12   93863.75       127320.38      2  0.714629
# 13     13   91992.39       135495.07      1  0.673644
# 14     14  119943.24       156547.42      2  0.664044
# 15     15  114523.61       122616.84      0  0.648921
# 16     16   78013.11       121597.55      1  0.632454
# 17     17   94657.16       145077.58      0  0.623317
# 18     18   91749.16       114175.79      2  0.617103
# 19     19   86419.70       153514.11      0  0.608713
# 20     20   76253.86       113867.30      1  0.584482
# 21     21   78389.47       153773.43      0  0.544157
# 22     22   73994.56       122782.75      2  0.538747
# 23     23   67532.53       105751.03      2  0.529634
# 24     24   77044.01        99281.34      0  0.528609
# 25     25   64664.71       139553.16      1  0.522146
# 26     26   75328.87       144135.98      2  0.512737
# 27     27   72107.60       127864.55      0  0.508654
# 28     28   66051.52       182645.56      2  0.498934
# 29     29   65605.48       153032.06      0  0.486108
# 30     30   61994.48       115641.28      2  0.480099
# 31     31   61136.38       152701.92      0  0.466280
# 32     32   63408.86       129219.61      1  0.465966
# 33     33   55493.95       103057.49      2  0.462312
# 34     34   46426.07       157693.92      1  0.461939
# 35     35   46014.02        85047.44      0  0.460626
# 36     36   28663.76       127056.21      2  0.428126
# 37     37   44069.95        51283.14      1  0.423852
# 38     39   38558.51        82982.09      1  0.373489
# 39     40   28754.33       118546.05      1  0.357914
# 40     41   27892.92        84710.77      2  0.355430
# 41     42   23640.93        96189.63      1  0.319951
# 42     43   15505.73       127382.30      0  0.310156
# 43     44   22177.74       154806.14      1  0.284485
# 44     45    1000.23       124153.04      0  0.282940
# 45     47       0.00       135426.92      1  0.156990
# 46     48     542.05        51743.15      0  0.118211

# %%
X = dm_new[["R&D Spend","Administration"]]             #============== Case-3
Y = dm_new["Profit"]

# %%
## Built full model
import statsmodels.api as sm

model2 = sm.OLS(Y, X)  # Capitalize OLS
model2 = model2.fit()

# %%
# Cook’s Distance

model_influence = model2.get_influence()
(cooks2 , P_value) = model_influence.cooks_distance
(cooks2 , P_value)

# Plot the influence values using the stemplot

fig = plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(dm_new)),np.round(cooks2,3))
plt.xlabel("Row index")
plt.ylabel("Cooks dis")
plt.show()

# %%
#index and value of influencer where c is more than 0.5
(np.argmax(cooks2),np.max(cooks2))
# Out:
# (2, 0.1273741437727375)

# %%
dm_new2 = dm_new.drop(dm_new.index[[2]],axis=0).reset_index()
dm_new2
# Out:
#     level_0  index  R&D Spend  Administration  State    Profit
# 0         0      0  165349.20       136897.80      0  1.000000
# 1         1      1  162597.70       151377.59      1  0.997355
# 2         3      3  144372.41       118671.85      0  0.947292
# 3         4      4  142107.34        91391.77      2  0.853171
# 4         5      5  131876.90        99814.71      0  0.801382
# 5         6      6  134615.46       147198.87      1  0.796490
# 6         7      7  130298.13       145530.06      2  0.794407
# 7         8      8  120542.52       148718.95      0  0.774468
# 8         9      9  123334.88       108679.17      1  0.760661
# 9        10     10  101913.08       110594.11      2  0.740175
# 10       11     11  100671.96        91790.61      1  0.729686
# 11       12     12   93863.75       127320.38      2  0.714629
# 12       13     13   91992.39       135495.07      1  0.673644
# 13       14     14  119943.24       156547.42      2  0.664044
# 14       15     15  114523.61       122616.84      0  0.648921
# 15       16     16   78013.11       121597.55      1  0.632454
# 16       17     17   94657.16       145077.58      0  0.623317
# 17       18     18   91749.16       114175.79      2  0.617103
# 18       19     19   86419.70       153514.11      0  0.608713
# 19       20     20   76253.86       113867.30      1  0.584482
# 20       21     21   78389.47       153773.43      0  0.544157
# 21       22     22   73994.56       122782.75      2  0.538747
# 22       23     23   67532.53       105751.03      2  0.529634
# 23       24     24   77044.01        99281.34      0  0.528609
# 24       25     25   64664.71       139553.16      1  0.522146
# 25       26     26   75328.87       144135.98      2  0.512737
# 26       27     27   72107.60       127864.55      0  0.508654
# 27       28     28   66051.52       182645.56      2  0.498934
# 28       29     29   65605.48       153032.06      0  0.486108
# 29       30     30   61994.48       115641.28      2  0.480099
# 30       31     31   61136.38       152701.92      0  0.466280
# 31       32     32   63408.86       129219.61      1  0.465966
# 32       33     33   55493.95       103057.49      2  0.462312
# 33       34     34   46426.07       157693.92      1  0.461939
# 34       35     35   46014.02        85047.44      0  0.460626
# 35       36     36   28663.76       127056.21      2  0.428126
# 36       37     37   44069.95        51283.14      1  0.423852
# 37       38     39   38558.51        82982.09      1  0.373489
# 38       39     40   28754.33       118546.05      1  0.357914
# 39       40     41   27892.92        84710.77      2  0.355430
# 40       41     42   23640.93        96189.63      1  0.319951
# 41       42     43   15505.73       127382.30      0  0.310156
# 42       43     44   22177.74       154806.14      1  0.284485
# 43       44     45    1000.23       124153.04      0  0.282940
# 44       45     47       0.00       135426.92      1  0.156990
# 45       46     48     542.05        51743.15      0  0.118211

# %%
dm_new2 =dm_new2.drop(["index"],axis=1)    #Drop newly created index column
dm_new2
# Out:
#     level_0  R&D Spend  Administration  State    Profit
# 0         0  165349.20       136897.80      0  1.000000
# 1         1  162597.70       151377.59      1  0.997355
# 2         3  144372.41       118671.85      0  0.947292
# 3         4  142107.34        91391.77      2  0.853171
# 4         5  131876.90        99814.71      0  0.801382
# 5         6  134615.46       147198.87      1  0.796490
# 6         7  130298.13       145530.06      2  0.794407
# 7         8  120542.52       148718.95      0  0.774468
# 8         9  123334.88       108679.17      1  0.760661
# 9        10  101913.08       110594.11      2  0.740175
# 10       11  100671.96        91790.61      1  0.729686
# 11       12   93863.75       127320.38      2  0.714629
# 12       13   91992.39       135495.07      1  0.673644
# 13       14  119943.24       156547.42      2  0.664044
# 14       15  114523.61       122616.84      0  0.648921
# 15       16   78013.11       121597.55      1  0.632454
# 16       17   94657.16       145077.58      0  0.623317
# 17       18   91749.16       114175.79      2  0.617103
# 18       19   86419.70       153514.11      0  0.608713
# 19       20   76253.86       113867.30      1  0.584482
# 20       21   78389.47       153773.43      0  0.544157
# 21       22   73994.56       122782.75      2  0.538747
# 22       23   67532.53       105751.03      2  0.529634
# 23       24   77044.01        99281.34      0  0.528609
# 24       25   64664.71       139553.16      1  0.522146
# 25       26   75328.87       144135.98      2  0.512737
# 26       27   72107.60       127864.55      0  0.508654
# 27       28   66051.52       182645.56      2  0.498934
# 28       29   65605.48       153032.06      0  0.486108
# 29       30   61994.48       115641.28      2  0.480099
# 30       31   61136.38       152701.92      0  0.466280
# 31       32   63408.86       129219.61      1  0.465966
# 32       33   55493.95       103057.49      2  0.462312
# 33       34   46426.07       157693.92      1  0.461939
# 34       35   46014.02        85047.44      0  0.460626
# 35       36   28663.76       127056.21      2  0.428126
# 36       37   44069.95        51283.14      1  0.423852
# 37       38   38558.51        82982.09      1  0.373489
# 38       39   28754.33       118546.05      1  0.357914
# 39       40   27892.92        84710.77      2  0.355430
# 40       41   23640.93        96189.63      1  0.319951
# 41       42   15505.73       127382.30      0  0.310156
# 42       43   22177.74       154806.14      1  0.284485
# 43       44    1000.23       124153.04      0  0.282940
# 44       45       0.00       135426.92      1  0.156990
# 45       46     542.05        51743.15      0  0.118211

# %% [markdown]
# # **Predict new improved model**

# %%
## Step-3 Split the variables as X and Y
x = dm_new2[["R&D Spend","Administration"]]             #============== Case-3   <<<Good>>>>
y = dm_new2["Profit"]

# %%
# Model fitting

from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(x,y)
# Out:
# LinearRegression()

# %%
# Model predicted values
y_pred = LR.predict(x)
y_pred
# Out:
# array([0.97386517, 0.95952679, 0.87836807, 0.87077522, 0.82234146,
#        0.82997459, 0.81009621, 0.76443066, 0.78170441, 0.68197642,
#        0.67823016, 0.64278385, 0.63321172, 0.7608056 , 0.73927152,
#        0.56975901, 0.64456251, 0.63437173, 0.60538637, 0.56241616,
#        0.56805133, 0.55096215, 0.52277005, 0.56765382, 0.50581575,
#        0.55486748, 0.54164977, 0.50762986, 0.50873857, 0.49597878,
#        0.4880113 , 0.50109125, 0.46713004, 0.41913332, 0.42502234,
#        0.33990339, 0.4196173 , 0.39060707, 0.34123829, 0.34087074,
#        0.31988367, 0.27873824, 0.3067896 , 0.21169486, 0.20583696,
#        0.21734416])

# %%
# Model evaluation

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y,y_pred)
print("Mean square error ",mse.round(3))

import numpy as np
print("Root mean square error ", np.sqrt(mse).round(3))
# Out:
# Mean square error  0.002
# Root mean square error  0.043

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y,y_pred)
print("r2_score",r2.round(3))
# Out:
# r2_score 0.955
